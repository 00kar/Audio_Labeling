# %%
import json

# %%
json_file_path = '/Users/karen/Downloads/1.ZED/ZED/Zed1_label_Karen.json'


with open(label_file_path, 'r') as labels_file:
    uploaded_labels = json.load(labels_file)


print(data["spk10_1.wav"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       4 with open(json_file_path, 'r') as json_file:
#       5     data = json.load(json_file)
# ----> 8 print(data[0]["spk10_1.wav"])
#
# KeyError: 'spk10_1.wav'

# %%
results = {}
for labeli in uploaded_labels:
    results[labeli['wav']] = {"emotion" : labeli['emo'], "length" : labeli['length']}

# %%
results
# Out:
# {'/Users/karen/Downloads/1.ZED/ZED/spk10_1.wav': {'emotion': 'sad',
#   'length': 2.93},
#  '/Users/karen/Downloads/1.ZED/ZED/spk10_2.wav': {'emotion': 'sad',
#   'length': 2.088},
#  '/Users/karen/Downloads/1.ZED/ZED/spk11_1.wav': {'emotion': 'hap',
#   'length': 4.614},
#  '/Users/karen/Downloads/1.ZED/ZED/spk11_2.wav': {'emotion': 'hap',
#   'length': 5.363},
#  '/Users/karen/Downloads/1.ZED/ZED/spk11_3.wav': {'emotion': 'neu',
#   'length': 5.018},
#  '/Users/karen/Downloads/1.ZED/ZED/spk11_4.wav': {'emotion': 'neu',
#   'length': 4.413},
#  '/Users/karen/Downloads/1.ZED/ZED/spk12_1.wav': {'emotion': 'neu',
#   'length': 5.203},
#  '/Users/karen/Downloads/1.ZED/ZED/spk12_2.wav': {'emotion': 'ang',
#   'length': 3.799},
#  '/Users/karen/Downloads/1.ZED/ZED/spk12_3.wav': {'emotion': 'sad',
#   'length': 4.889},
#  '/Users/karen/Downloads/1.ZED/ZED/spk12_4.wav': {'emotion': 'sad',
#   'length': 3.498},
#  '/Users/karen/Downloads/1.ZED/ZED/spk12_5.wav': {'emotion': 'sad',
# ...
